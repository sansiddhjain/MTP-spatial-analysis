# %%
import pandas as pd
import numpy as np

# %%
df_bf = pd.read_csv("temp/cdf-clustering/BF_ADV/KMeans/labels.csv")
del df_bf["Unnamed: 0"]
df_fc = pd.read_csv("temp/cdf-clustering/FC_ADV/KMeans/labels.csv")
del df_fc["Unnamed: 0"]

# %%
df_bf.columns = ['District', 'BF_ADV_Cluster']
df_fc.columns = ['District', 'FC_ADV_Cluster']

# %%
df = df_fc.merge(df_bf)

# %%
df
# Out:
#      District  FC_ADV_Cluster  BF_ADV_Cluster
# 0         203               2               1
# 1         204               2               1
# 2         205               4               4
# 3         206               2               1
# 4         207               0               3
# 5         208               4               3
# 6         209               4               1
# 7         210               3               3
# 8         211               5               6
# 9         212               1               4
# 10        213               2               2
# 11        214               4               3
# 12        215               2               1
# 13        216               2               1
# 14        217               2               1
# 15        218               2               1
# 16        219               2               1
# 17        220               2               1
# 18        221               2               1
# ...
